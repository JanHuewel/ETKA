# %%
import glob 
import pandas as pd
import numpy as np
import pprint
from statsmodels.tsa.stattools import adfuller, kpss
import matplotlib.pyplot as plt

# %%
list_of_datasets = glob.glob('lloyd_et_al/*.csv')
list_of_datasets = sorted(list_of_datasets, key=lambda x: int(x.split('\\')[1].split('_')[0][1:]))

# %%
list_of_datasets.pop(2)
list_of_datasets.pop(2)
list_of_datasets.pop(2)
# Out:
# 'lloyd_et_al\\d5_jena.csv'

# %%
list_of_datasets=list_of_datasets[:-3]

# %%
# %matplotlib notebook 
stats = {}
fig, axs = plt.subplots(nrows=14, ncols=1)
i =0
for dataset in list_of_datasets:
    name = dataset.split('\\')[1][:-4]
    stats[name] = {}
    dataframe = pd.read_csv(dataset).dropna()
    if 'solar' in dataset:
        y = 'cycle'
    elif 'mauna' in dataset:
        y = 'Carbon Dioxide (ppm)'
    elif 'airquality' in dataset:
        y = 'COx'
    else:
        y = 'y'
    try:
        stats[name]['length'] = int(dataframe[y].shape[0])
        stats[name]['mean'] = dataframe[y].mean()
        stats[name]['std'] = dataframe[y].std()
        stats[name]['var'] = dataframe[y].var()
        stats[name]['min'] = dataframe[y].min()
        stats[name]['max'] = dataframe[y].max()
        adf = adfuller(dataframe[y])
        kpss_res = kpss(dataframe[y], nlags='auto')
        #stats[name]['adf_nonstationary'] = adf[0] < adf[4]['5%']
        #stats[name]['kpss_nonstationary'] = kpss_res[0] > kpss_res[3]['5%']
        print(dataset)
        dataframe[y].plot(ax=axs[i])
        axs[i].set_title(dataset)
        i+=1
    except Exception as exc:
        print(exc)
pprint.PrettyPrinter(depth=4).pprint(stats)
# Out:
# <img src="data:image/png;base64,..." width="799.5333333333333">
# C:\Users\ge59sek\Anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1906: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   warnings.warn(
# C:\Users\ge59sek\Anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1906: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   warnings.warn(
# C:\Users\ge59sek\Anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1906: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   warnings.warn(
# C:\Users\ge59sek\Anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1906: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   warnings.warn(
# C:\Users\ge59sek\Anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1910: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(
# C:\Users\ge59sek\Anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1906: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   warnings.warn(
# lloyd_et_al\d1_solar_irradiance.csv
# lloyd_et_al\d2_maunaloa.csv
# lloyd_et_al\d6_airline.csv
# lloyd_et_al\d7_wheat.csv
# lloyd_et_al\d8_temperature.csv
# lloyd_et_al\d9_internet.csv
# C:\Users\ge59sek\Anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1910: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(
# C:\Users\ge59sek\Anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1910: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(
# C:\Users\ge59sek\Anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1906: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   warnings.warn(
# C:\Users\ge59sek\Anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1906: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   warnings.warn(
# C:\Users\ge59sek\Anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1906: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   warnings.warn(
# lloyd_et_al\d10_call-centre.csv
# lloyd_et_al\d11_radio.csv
# lloyd_et_al\d12_gas-production.csv
# lloyd_et_al\d13_sulphuric.csv
# lloyd_et_al\d14_unemployment.csv
# lloyd_et_al\d15_births.csv
# C:\Users\ge59sek\Anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1906: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   warnings.warn(
# lloyd_et_al\d16_wages.csv
# lloyd_et_al\d17_airquality.csv
# {'d10_call-centre': {'adf_nonstationary': False,
#                      'kpss_nonstationary': False,
#                      'length': 180,
#                      'max': 872.0,
#                      'mean': 492.5,
#                      'min': 161.0,
#                      'std': 189.53664464900837,
#                      'var': 35924.13966480447},
#  'd11_radio': {'adf_nonstationary': False,
#                'kpss_nonstationary': False,
#                'length': 240,
#                'max': 13.5,
#                'mean': 8.07833333333333,
#                'min': 4.3,
#                'std': 2.441283129705837,
#                'var': 5.959863319386327},
#  'd12_gas-production': {'adf_nonstationary': False,
#                         'kpss_nonstationary': True,
#                         'length': 476,
#                         'max': 66600.0,
#                         'mean': 21415.27100840336,
#                         'min': 1646.0,
#                         'std': 18678.33773005454,
#                         'var': 348880300.35797894},
#  'd13_sulphuric': {'adf_nonstationary': False,
#                    'kpss_nonstationary': True,
#                    'length': 462,
#                    'max': 228.0,
#                    'mean': 131.34199134199133,
#                    'min': 42.0,
#                    'std': 41.263398280734776,
#                    'var': 1702.6680376745455},
#  'd14_unemployment': {'adf_nonstationary': False,
#                       'kpss_nonstationary': True,
#                       'length': 408,
#                       'max': 1350.0,
#                       'mean': 520.281862745098,
#                       'min': 122.0,
#                       'std': 261.2225866354436,
#                       'var': 68237.23976851182},
#  'd15_births': {'adf_nonstationary': True,
#                 'kpss_nonstationary': True,
#                 'length': 1000,
#                 'max': 366.0,
#                 'mean': 248.534,
#                 'min': 136.0,
#                 'std': 42.05698079550688,
#                 'var': 1768.7896336336346},
#  'd16_wages': {'adf_nonstationary': False,
#                'kpss_nonstationary': True,
#                'length': 735,
#                'max': 49.99,
#                'mean': 8.764544217687076,
#                'min': 2.15,
#                'std': 8.17736955153934,
#                'var': 66.8693727824427},
#  'd17_airquality': {'adf_nonstationary': True,
#                     'kpss_nonstationary': True,
#                     'length': 7718,
#                     'max': 1479.0,
#                     'mean': 246.8967349054159,
#                     'min': 2.0,
#                     'std': 212.97916810358612,
#                     'var': 45360.1260460956},
#  'd1_solar_irradiance': {'adf_nonstationary': False,
#                          'kpss_nonstationary': True,
#                          'length': 391,
#                          'max': 1366.6829,
#                          'mean': 1365.8159831202047,
#                          'min': 1365.5165,
#                          'std': 0.24418387076133838,
#                          'var': 0.059625762739990006},
#  'd2_maunaloa': {'adf_nonstationary': False,
#                  'kpss_nonstationary': True,
#                  'length': 702,
#                  'max': 407.65,
#                  'mean': 352.2983333333327,
#                  'min': 313.21,
#                  'std': 26.180378817377672,
#                  'var': 685.4122350213976},
#  'd6_airline': {'adf_nonstationary': False,
#                 'kpss_nonstationary': True,
#                 'length': 144,
#                 'max': 622.0,
#                 'mean': 280.2986111111111,
#                 'min': 104.0,
#                 'std': 119.96631694294321,
#                 'var': 14391.917200854701},
#  'd7_wheat': {'adf_nonstationary': False,
#               'kpss_nonstationary': True,
#               'length': 370,
#               'max': 381.0,
#               'mean': 107.8764864864865,
#               'min': 11.0,
#               'std': 67.20805469843667,
#               'var': 4516.922616348055},
#  'd8_temperature': {'adf_nonstationary': True,
#                     'kpss_nonstationary': False,
#                     'length': 1000,
#                     'max': 26.3,
#                     'mean': 11.206300000000006,
#                     'min': -0.8,
#                     'std': 4.144073316635898,
#                     'var': 17.17334365365365},
#  'd9_internet': {'adf_nonstationary': False,
#                  'kpss_nonstationary': True,
#                  'length': 1000,
#                  'max': 125058.789943813,
#                  'mean': 46355.45025916609,
#                  'min': 13486.7421531532,
#                  'std': 22058.929761275198,
#                  'var': 486596382.2128726}}
# C:\Users\ge59sek\Anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1906: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   warnings.warn(

# %%
df = pd.DataFrame(stats).transpose()

# %%
df
# Out:
#                     length          mean           std               var  \
# d1_solar_irradiance    391   1365.815983      0.244184          0.059626
# d2_maunaloa            702    352.298333     26.180379        685.412235
# d6_airline             144    280.298611    119.966317      14391.917201
# d7_wheat               370    107.876486     67.208055       4516.922616
# d8_temperature        1000       11.2063      4.144073         17.173344
# d9_internet           1000  46355.450259  22058.929761  486596382.212873
# d10_call-centre        180         492.5    189.536645      35924.139665
# d11_radio              240      8.078333      2.441283          5.959863
# d12_gas-production     476  21415.271008   18678.33773  348880300.357979
# d13_sulphuric          462    131.341991     41.263398       1702.668038
# d14_unemployment       408    520.281863    261.222587      68237.239769
# d15_births            1000       248.534     42.056981       1768.789634
# d16_wages              735      8.764544       8.17737         66.869373
# d17_airquality        7718    246.896735    212.979168      45360.126046
#
#                               min            max adf_nonstationary  \
# d1_solar_irradiance     1365.5165      1366.6829             False
# d2_maunaloa                313.21         407.65             False
# d6_airline                  104.0          622.0             False
# d7_wheat                     11.0          381.0             False
# d8_temperature               -0.8           26.3              True
# d9_internet          13486.742153  125058.789944             False
# d10_call-centre             161.0          872.0             False
# d11_radio                     4.3           13.5             False
# d12_gas-production         1646.0        66600.0             False
# d13_sulphuric                42.0          228.0             False
# d14_unemployment            122.0         1350.0             False
# d15_births                  136.0          366.0              True
# d16_wages                    2.15          49.99             False
# d17_airquality                2.0         1479.0              True
#
#                     kpss_nonstationary
# d1_solar_irradiance               True
# d2_maunaloa                       True
# d6_airline                        True
# d7_wheat                          True
# d8_temperature                   False
# d9_internet                       True
# d10_call-centre                  False
# d11_radio                        False
# d12_gas-production                True
# d13_sulphuric                     True
# d14_unemployment                  True
# d15_births                        True
# d16_wages                         True
# d17_airquality                    True

# %%
pd.read_csv(list_of_datasets[1]).dropna()
# Out:
#      Year  Month  Decimal Date  Carbon Dioxide (ppm)  \
# 2    1958      3     1958.2027                315.69
# 3    1958      4     1958.2877                317.45
# 4    1958      5     1958.3699                317.50
# 6    1958      7     1958.5370                315.86
# 7    1958      8     1958.6219                314.93
# ..    ...    ...           ...                   ...
# 704  2016      9     2016.7077                401.01
# 705  2016     10     2016.7896                401.50
# 706  2016     11     2016.8743                403.64
# 707  2016     12     2016.9563                404.55
# 708  2017      1     2017.0411                406.07
#
#      Seasonally Adjusted CO2 (ppm)  Carbon Dioxide Fit (ppm)  \
# 2                           314.42                    316.18
# 3                           315.15                    317.30
# 4                           314.73                    317.83
# 6                           315.17                    315.87
# 7                           316.17                    314.01
# ..                             ...                       ...
# 704                         404.52                    401.33
# 705                         405.12                    401.48
# 706                         405.92                    403.08
# 707                         405.49                    404.66
# 708                         406.04                    405.87
#
#      Seasonally Adjusted CO2 Fit (ppm)
# 2                               314.89
# 3                               314.98
# 4                               315.06
# 6                               315.21
# 7                               315.29
# ..                                 ...
# 704                             404.85
# 705                             405.09
# 706                             405.34
# 707                             405.58
# 708                             405.83
#
# [702 rows x 7 columns]

# %%
adf
# Out:
# (-6.682197197363337,
#  4.314062041915778e-09,
#  35,
#  7682,
#  {'1%': -3.431201534294984,
#   '5%': -2.8619163150009173,
#   '10%': -2.566970307948449},
#  89391.17938035679)
